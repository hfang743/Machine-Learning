# %% [markdown]
# # PS1-Q2: Housing Price Visualization

# %% [markdown]
# **Your Name:**Haixiang Fang
#
# **People I discussed this assignment with:**None

# %% [markdown]
# # California Housing Dataset Starter Code
# The below code is a useful starting point that should get you started with exploring the California Housing data.

# %%
import numpy as np
from sklearn.datasets.california_housing import fetch_california_housing
cal_housing = fetch_california_housing('.')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
print(cal_housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# ...

# %%
X = cal_housing.data
avg_price = cal_housing.target
feature_names = cal_housing.feature_names
feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# Some people might find it useful to use a [Pandas](http://synesthesiam.com/posts/an-introduction-to-pandas.html) [dataframe](http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/) to [manipulate the data](http://www.gregreda.com/2013/10/26/working-with-pandas-dataframes/), but that is not really required for basic plotting and visualization:

# %%
import pandas as pd
df=pd.DataFrame(np.hstack([X,avg_price[ :,np.newaxis]]),columns=np.hstack([feature_names,'price']))
#Example of the first few rows of data (using the "head" command)
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# Below is how you might select only some columns from a dataframe.
# This is just an illustrative example; you could select other columns
subdf = df[['MedInc','HouseAge','AveRooms','AveBedrms','Population','AveOccup','price']]
subdf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  price
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556  4.526
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842  3.585
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260  3.521
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945  3.413
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467  3.422

# %% [markdown]
# For the below tasks, you might want to try out some basic Python plotting libraries. I recommend:
#
# * [Matplotlib](http://matplotlib.org/): Fairly basic building block, but gets the job done, and widely used. This is the most complicated option, but gives you the most control.
# * [Bokeh](http://bokeh.pydata.org/en/latest/): Fancier interactive graphs with scrolling. Fairly easy to use.
# * [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/): Probably the easiest to use to produce basic, common graphs and statistics.
#
# If you aren't familiar with any of the above libraries, I would suggest starting with Seaborn, since it hides many of the complex features you might not need right away (check out their [tutorial](https://stanford.edu/~mwaskom/software/seaborn/tutorial/distributions.html)). Bokeh also has a nice [Quick Start guide](http://bokeh.pydata.org/en/latest/docs/user_guide/quickstart.html#userguide-quickstart) if you like having the ability to pan/zoom the data.

# %%
# Matplotlib plotting example
# Below line tells the notebook to plots the images here
# in the notebook, rather than separately as image files.
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.hist(df['MedInc'])
# Out:
# (array([2247., 7436., 6098., 2990., 1060.,  428.,  178.,   93.,   47.,
#           63.]),
#  array([ 0.4999 ,  1.94992,  3.39994,  4.84996,  6.29998,  7.75   ,
#          9.20002, 10.65004, 12.10006, 13.55008, 15.0001 ]),
#  <a list of 10 Patch objects>)

# %%
# Pandas Example- Uncomment below and run if you want
# Note, this is essentially just a shortcut to matplotlib
#df['MedInc'].plot.hist()

# %%
# Seaborn Example - Uncomment below and run if you want
#import seaborn as sns  
# Note, just importing seaborn changes the matplotlib default behavior
#sns.distplot(df['MedInc'])

# %% [markdown]
# # Task 1: Visualize the relationship between features and price
# Visualize the 2D relationship between housing prices and the provided features of the data. You can choose how you want to do this.
#
# [Enter your code into the empty cell below to create the necessary visualizations. You can create multiple cells for code or Markdown code if that helps you craft your submission.]

# %%
plt.scatter(df['MedInc'],df['price'])
plt.xlabel("MedInc")
plt.show()
plt.scatter(df['HouseAge'],df['price'])
plt.xlabel("HouseAge")
plt.show()
plt.scatter(df['AveRooms'],df['price'])
plt.xlabel("AveRooms")
plt.show()
plt.scatter(df['AveBedrms'],df['price'])
plt.xlabel("AveBedrms")
plt.show()
plt.scatter(df['Population'],df['price'])
plt.xlabel("Population")
plt.show()
plt.scatter(df['AveOccup'],df['price'])
plt.xlabel("Ave")
plt.show()

# %% [markdown]
# **Question**: Do any of the features appear linearly correlated with price?
#
# **Student Response:**Only part of the data of median income shows linear corelations with price.

# %% [markdown]
# # Task 2: Visualize the relationships between features
# Visualize the 1D and 2D relationships between the features in the dataset.

# %%
#1D
plt.hist(df['MedInc'])
plt.xlabel("MedInc")
plt.show()
plt.hist(df['HouseAge'])
plt.xlabel("HouseAge")
plt.show()
plt.hist(df['AveRooms'])
plt.xlabel("AveRooms")
plt.show()
plt.hist(df['AveBedrms'])
plt.xlabel("AveBedrms")
plt.show()
plt.hist(df['Population'])
plt.xlabel("Population")
plt.show()
plt.hist(df['AveOccup'])
plt.xlabel("AveOccup")
plt.show()
plt.hist(df['price'])
plt.xlabel("price")
plt.show()

# %%
#2D
plt.scatter(df['MedInc'],df['HouseAge'])
plt.xlabel("MedInc")
plt.ylabel("HouseAge")
plt.show()
plt.scatter(df['MedInc'],df['AveRooms'])
plt.xlabel("MedInc")
plt.ylabel("AveRooms")
plt.show()
plt.scatter(df['MedInc'],df['AveBedrms'])
plt.xlabel("MedInc")
plt.ylabel("AveBedrms")
plt.show()
plt.scatter(df['MedInc'],df['Population'])
plt.xlabel("MedInc")
plt.ylabel("Population")
plt.show()
plt.scatter(df['MedInc'],df['AveOccup'])
plt.xlabel("MedInc")
plt.ylabel("AveOccup")
plt.show()
plt.scatter(df['AveRooms'],df['AveBedrms'])
plt.xlabel("AveRooms")
plt.ylabel("AveBedrms")
plt.show()
plt.scatter(df['AveRooms'],df['Population'])
plt.xlabel("AveRooms")
plt.ylabel("Population")
plt.show()
plt.scatter(df['AveRooms'],df['AveOccup'])
plt.xlabel("AveRooms")
plt.ylabel("AveOccup")
plt.show()
plt.scatter(df['AveBedrms'],df['Population'])
plt.xlabel("AveBedrms")
plt.ylabel("Population")
plt.show()
plt.scatter(df['AveBedrms'],df['AveOccup'])
plt.xlabel("AveBedrms")
plt.ylabel("AveOccup")
plt.show()
plt.scatter(df['Population'],df['AveOccup'])
plt.xlabel("Population")
plt.ylabel("AveOccup")
plt.show()

# %% [markdown]
# **Question**: Are there any anomalies that look strange in the data, and which visualization helped you identify them (hint: there should be)?
#
# **Student Response:** From 1D visualizations, we can observe that many of the features are highly concentrated, including average rooms, average bedrooms, polulation and average occupation. From 2D visualizations, most of the data points layed uniformly on the figures except average rooms to average bedrooms. We can easily observe those discrete points as anomalies.

# %% [markdown]
# # (743 Only) Task 3: Visualize relationships w/ Anomalies Removed.
# Using your knowledge of the anomalies you found above, remove those anomalies using appropriate code below (either by removing the entire data record, or just the specific values that were anomalous, if you prefer to be more surgical) and replot the Task 1 and Task 2 plots you produced above.

# %%
#Shrink datasets by eliminating discrete points 
#Method 1 
df.AveBedrms.plot(kind='box')

# %%
df1=df[df.AveBedrms<20]

# %%
df1.AveBedrms.plot(kind='box')

# %%
plt.scatter(df1['MedInc'],df1['AveBedrms'])
plt.xlabel("MedInc")
plt.ylabel("AveBedrms")
# Out:
# Text(0, 0.5, 'AveBedrms')

# %%
df.Population.plot(kind='box')

# %%
df2=df[df.Population<20000]
plt.scatter(df2['MedInc'],df2['Population'])
plt.xlabel("MedInc")
plt.ylabel("Population")
plt.show()

# %%
df.AveOccup.plot(kind='box')

# %%
df3=df[df.AveOccup<200]
plt.scatter(df3['MedInc'],df3['AveOccup'])
plt.xlabel("MedInc")
plt.ylabel("AveOccup")
plt.show()

# %%
df.AveRooms.plot(kind='box')

# %%
df4=df[df.AveRooms<80]
plt.scatter(df4['MedInc'],df4['AveRooms'])
plt.xlabel("MedInc")
plt.ylabel("AveRooms")
plt.show()

# %%
df4.AveBedrms.plot(kind='box')

# %%
plt.scatter(df4['AveRooms'],df4['AveBedrms'])
plt.xlabel("AveRooms")
plt.ylabel("AveBedrms")
plt.show()

# %%
#Method 2
slcdf = df[df['AveRooms']<= sum(df['AveRooms']/len(df['AveRooms'])*4)]
slcdf = df[df['AveBedrms']<= sum(df['AveBedrms']/len(df['AveBedrms'])*4)]
slcdf = df[df['Population']<= sum(df['Population']/len(df['Population'])*4)]
slcdf = df[df['AveOccup']<= sum(df['AveOccup']/len(df['AveOccup'])*2)]

# %%
slcdf = df[df['AveRooms']<= sum(df['AveRooms']/len(df['AveRooms'])*4)]
plt.scatter(slcdf['MedInc'],slcdf['AveRooms'])
plt.xlabel("MedInc")
plt.ylabel("AveRooms")
plt.show()
slcdf = df[df['AveBedrms']<= sum(df['AveBedrms']/len(df['AveBedrms'])*4)]
plt.scatter(df['MedInc'],df['AveBedrms'])
plt.xlabel("MedInc")
plt.ylabel("AveBedrms")
plt.show()
slcdf = df[df['Population']<= sum(df['Population']/len(df['Population'])*4)]
plt.scatter(df['MedInc'],df['Population'])
plt.xlabel("MedInc")
plt.ylabel("Population")
plt.show()
slcdf = df[df['AveOccup']<= sum(df['AveOccup']/len(df['AveOccup'])*2)]
plt.scatter(df['MedInc'],df['AveOccup'])
plt.xlabel("MedInc")
plt.ylabel("AveOccup")
plt.show()
slcdf = df[df['AveRooms']<= sum(df['AveRooms']/len(df['AveRooms'])*4)]
plt.scatter(slcdf['AveRooms'],slcdf['AveBedrms'])
plt.xlabel("AveRooms")
plt.ylabel("AveBedrms")
plt.show()
slcdf = df[df['AveBedrms']<= sum(df['AveBedrms']/len(df['AveBedrms'])*4)]
plt.scatter(df['AveRooms'],df['Population'])
plt.xlabel("AveRooms")
plt.ylabel("Population")
plt.show()
slcdf = df[df['AveOccup']<= sum(df['AveOccup']/len(df['AveOccup'])*2)]
plt.scatter(df['AveRooms'],df['AveOccup'])
plt.xlabel("AveRooms")
plt.ylabel("AveOccup")
plt.show()
slcdf = df[df['AveRooms']<= sum(df['AveRooms']/len(df['AveRooms'])*4)]
plt.scatter(df['AveBedrms'],df['Population'])
plt.xlabel("AveBedrms")
plt.ylabel("Population")
plt.show()
slcdf = df[df['AveOccup']<= sum(df['AveOccup']/len(df['AveOccup'])*2)]
plt.scatter(df['AveBedrms'],df['AveOccup'])
plt.xlabel("AveBedrms")
plt.ylabel("AveOccup")
# Out:
# Text(0, 0.5, 'AveOccup')

# %% [markdown]
# **Question**: Does this change your answer to the original Task 1 or Task 2 questions?
#
# **Student Response:** Yes. After eliminating abnormal individual data, the results show better linear correlations.

# %% [markdown]
# # Submitting your assignment
#
# You should submit this IPython notebook assignment to Canvas in two formats:
#
# 1. as a PDF. There are multiple ways to do this, but the way I recommend is to go to "File -> Print Preview" and then save that page as a PDF (either directly, or by printing it as a PDF). There a "Download as -> PDF via LaTeX" option, but I find that it often messes up figures and formatting, making it more effort than it is worth. Always double check your PDF submission to make sure everything is there before uploading it to Canvas, since the PDF document is what I will grade initially.
# 2. as the raw Jupyter/IPython notebook. This is easier, since you just upload your .ipynb file directly. This is an experimental feature that I am testing with the Canvas API that might enable easier submissions in the future, but it is still a bit buggy, so I am asking folks to also submit a PDF printout just so that things don't accidentally get messed up.
